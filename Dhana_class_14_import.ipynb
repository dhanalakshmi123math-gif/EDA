# %%
import <package name>
import ADDITION
# Out:
#   Cell In[1], line 1
#     import <package name>
#            ^
# SyntaxError: invalid syntax

# %%
# package name: random
import random

# %%
# package name: math
import math

# %%
# package name: time
import time

# %%
# package name: cv2 (computer vision 2)
import cv2
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[8], line 2
#       1 # package name: cv2 (computer vision 2)
# ----> 2 import cv2
#
# ModuleNotFoundError: No module named 'cv2'

# %%
import random

# %%
random
# Out:
# <module 'random' from 'C:\\Users\\dell\\anaconda3\\Lib\\random.py'>

# %%
Dhana is very happy
addition
subtraction
multiplication
division

Hey Dhana how you want share again

case-1: keep all add sub mi=ul div in one python file
case-2: create each seperate file then 
        keep in a box give to me

# %%
# we liked first one
# module
# single python file
# module: MathFunction   uncle
#      add               kid1 : cricket
#      sub               kid2 : story teller
#      mul               kid3 : football
#      div               kid4 : artist

# %%
import random
dir(random)
# Out:
# ['BPF',
#  'LOG4',
#  'NV_MAGICCONST',
#  'RECIP_BPF',
#  'Random',
#  'SG_MAGICCONST',
#  'SystemRandom',
#  'TWOPI',
#  '_ONE',
#  '_Sequence',
#  '__all__',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  '_accumulate',
#  '_acos',
#  '_bisect',
#  '_ceil',
#  '_cos',
#  '_e',
#  '_exp',
#  '_fabs',
#  '_floor',
#  '_index',
#  '_inst',
#  '_isfinite',
#  '_lgamma',
#  '_log',
#  '_log2',
#  '_os',
#  '_parse_args',
#  '_pi',
#  '_random',
#  '_repeat',
#  '_sha512',
#  '_sin',
#  '_sqrt',
#  '_test',
#  '_test_generator',
#  '_urandom',
#  'betavariate',
#  'binomialvariate',
#  'choice',
#  'choices',
#  'expovariate',
#  'gammavariate',
#  'gauss',
#  'getrandbits',
#  'getstate',
#  'lognormvariate',
#  'main',
#  'normalvariate',
#  'paretovariate',
#  'randbytes',
#  'randint',
#  'random',
#  'randrange',
#  'sample',
#  'seed',
#  'setstate',
#  'shuffle',
#  'triangular',
#  'uniform',
# ...

# %%
# step-1: import <module>
# step-2: dir(<module>)

import math
dir(math) # practice below methods doc etc
# Out:
# ['__doc__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  'acos',
#  'acosh',
#  'asin',
#  'asinh',
#  'atan',
#  'atan2',
#  'atanh',
#  'cbrt',
#  'ceil',
#  'comb',
#  'copysign',
#  'cos',
#  'cosh',
#  'degrees',
#  'dist',
#  'e',
#  'erf',
#  'erfc',
#  'exp',
#  'exp2',
#  'expm1',
#  'fabs',
#  'factorial',
#  'floor',
#  'fma',
#  'fmod',
#  'frexp',
#  'fsum',
#  'gamma',
#  'gcd',
#  'hypot',
#  'inf',
#  'isclose',
#  'isfinite',
#  'isinf',
#  'isnan',
#  'isqrt',
#  'lcm',
#  'ldexp',
#  'lgamma',
#  'log',
#  'log10',
#  'log1p',
#  'log2',
#  'modf',
#  'nan',
#  'nextafter',
#  'perm',
#  'pi',
#  'pow',
#  'prod',
#  'radians',
#  'remainder',
#  'sin',
#  'sinh',
#  'sqrt',
#  'sumprod',
#  'tan',
#  'tanh',
#  'tau',
#  'trunc',
#  'ulp']

# %%
import random
random.random
# Out:
# <function Random.random()>

# %%
import random
random.random()
# Out:
# 0.9637673936074347

# %%
# step-1: import modulename
# step-2: inorder to methods apply directory
#         dir(modulename)
# step-3: choose one method
#         modulename.methodname
# if above one is function it will say function or method
# we need to add brackets

# if above one not a function it will give direct values
# step-4: apply the brackets perform the shift+tab
#         modulename.methodname()

# step-5: Read the doc string undertand it and use it

# %%
import random
dir(random) # practice below methods BPF etc
# Out:
# ['BPF',
#  'LOG4',
#  'NV_MAGICCONST',
#  'RECIP_BPF',
#  'Random',
#  'SG_MAGICCONST',
#  'SystemRandom',
#  'TWOPI',
#  '_ONE',
#  '_Sequence',
#  '__all__',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  '_accumulate',
#  '_acos',
#  '_bisect',
#  '_ceil',
#  '_cos',
#  '_e',
#  '_exp',
#  '_fabs',
#  '_floor',
#  '_index',
#  '_inst',
#  '_isfinite',
#  '_lgamma',
#  '_log',
#  '_log2',
#  '_os',
#  '_parse_args',
#  '_pi',
#  '_random',
#  '_repeat',
#  '_sha512',
#  '_sin',
#  '_sqrt',
#  '_test',
#  '_test_generator',
#  '_urandom',
#  'betavariate',
#  'binomialvariate',
#  'choice',
#  'choices',
#  'expovariate',
#  'gammavariate',
#  'gauss',
#  'getrandbits',
#  'getstate',
#  'lognormvariate',
#  'main',
#  'normalvariate',
#  'paretovariate',
#  'randbytes',
#  'randint',
#  'random',
#  'randrange',
#  'sample',
#  'seed',
#  'setstate',
#  'shuffle',
#  'triangular',
#  'uniform',
# ...

# %%
random.random
# Out:
# <function Random.random()>

# %%
random.random()
# Out:
# 0.7458115638815248

# %%
random() -> x in the interval [0, 1).

# %%
import random  # step-1
dir(random)  # step-2
random.random   # step-3
random.random()  # step-4 & step-5
random() -> x in the interval [0, 1).

# %%
# package name : random
# attribute name : randint

# %%
import random 
random.randint
# Out:
# <bound method Random.randint of <random.Random object at 0x00000208DD39FF50>>

# %%
import random 
random.randint(1,6) # don't give 6,1. error
# Out:
# 4

# %%
Return random integer in range [a, b], including both end points.

# %%
random.randint()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 random.randint()
#
# TypeError: Random.randint() missing 2 required positional arguments: 'a' and 'b'

# %%
random.randint(2)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 random.randint(2)
#
# TypeError: Random.randint() missing 1 required positional argument: 'b'

# %%
# package name       method name

random               random
random               randint
random               uniform
random               sample      random.sample([10,20,30,40])
random               choice      random.choice(<use list inside>)
random               shuffle

n = [10,20,30,40]
random.shuffle(n)
print(n)


math                 sqrt
math                 sin
math                 pi
math                 e
math                 pow

# %%
import random 
random.uniform
random.uniform(10,11)
# Out:
# 10.161610151421462

# %%
Get a random number in the range [a, b) or [a, b] depending on rounding.

The mean (expected value) and variance of the random variable are:

    E[X] = (a + b) / 2
    Var[X] = (b - a) ** 2 / 12

# %%
random.sample
random.sample([10,20,30,40,50],2) # 2 is k value & 10 to 45 are population
# Out:
# [20, 50]

# %%
n=[10,20,30,40,50] 
k=2
random.sample(n,k)
# Out:
# [50, 30]

# %%
# Important points:

# random.sample() returns different results each time
# It never repeats elements
# Order of output is random

# %%
Choose a random element from a non-empty sequence.

# %%
n=[10,20,30]
random.choice(n)
# Out:
# 30

# %%
print(n)
# Out:
# [10, 20, 30]

# %%
n=[10,20,30,40]
random.shuffle(n)
print(n)
# Out:
# [20, 10, 40, 30]

# %%
# sample == some values will be selected
# choise == one value choise
# shuffle == mix

# %%
import math  # without import also we can generate math.sqrt
math.sqrt
# Out:
# <function math.sqrt(x, /)>

# %%
math.sqrt(4)
# Out:
# 2.0

# %%
math.pi
# Out:
# 3.141592653589793

# %%
math.pi*3  # pi*3
# Out:
# 9.42477796076938

# %%
math.sin
# Out:
# <function math.sin(x, /)>

# %%
math.sin(90)
# Out:
# 0.8939966636005579

# %%
math.sin(90)**3
# Out:
# 0.7145089843182212

# %%
math.e # represents Euler’s number (e)
# Out:
# 7.3890560989306495

# %%
math.e**1  # e^1
# Out:
# 2.718281828459045

# %%
math.pow
# Out:
# <function math.pow(x, y, /)>

# %%
math.pow(2,3) # 2^3
# Out:
# 8.0

# %%
import keyword
dir(keyword)
# Out:
# ['__all__',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  'iskeyword',
#  'issoftkeyword',
#  'kwlist',
#  'softkwlist']

# %%
keyword.kwlist
# Out:
# ['False',
#  'None',
#  'True',
#  'and',
#  'as',
#  'assert',
#  'async',
#  'await',
#  'break',
#  'class',
#  'continue',
#  'def',
#  'del',
#  'elif',
#  'else',
#  'except',
#  'finally',
#  'for',
#  'from',
#  'global',
#  'if',
#  'import',
#  'in',
#  'is',
#  'lambda',
#  'nonlocal',
#  'not',
#  'or',
#  'pass',
#  'raise',
#  'return',
#  'try',
#  'while',
#  'with',
#  'yield']

# %%
len(keyword.kwlist)
# Out:
# 35

# %%
import time
print('hello')
# Out:
# hello

# %%
time.sleep(5)  # 5 = after 5 secconds output (hello) will be generated
print('hello')
# Out:
# hello

# %%
import time
time.time()
# Out:
# 1768490675.4865572

# %%
import time
dir(time)
# Out:
# ['_STRUCT_TM_ITEMS',
#  '__doc__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  'altzone',
#  'asctime',
#  'ctime',
#  'daylight',
#  'get_clock_info',
#  'gmtime',
#  'localtime',
#  'mktime',
#  'monotonic',
#  'monotonic_ns',
#  'perf_counter',
#  'perf_counter_ns',
#  'process_time',
#  'process_time_ns',
#  'sleep',
#  'strftime',
#  'strptime',
#  'struct_time',
#  'thread_time',
#  'thread_time_ns',
#  'time',
#  'time_ns',
#  'timezone',
#  'tzname']

# %%
TWOPI

# %%
Go through the Text Book
