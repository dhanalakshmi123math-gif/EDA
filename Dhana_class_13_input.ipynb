# %%
input
# Out:
# <bound method Kernel.raw_input of <ipykernel.ipkernel.IPythonKernel object at 0x000001C1D394DE80>>

# %% [markdown]
# - bound method
# - function
# - we need to add brackets

# %%
input() # shift+enter
# Out:
#  10 # click on enter
# '10 # click on enter'

# %%
input()
# Out:
#  hi bro
# 'hi bro'

# %%
input()
input()
# Out:
#  10
#  20
# '20'

# %%
input("Enter the number1:")
input("Enter the number2:")
# Out:
# Enter the number1: 10
# Enter the number2: 20
# '20'

# %%
a=input("Enter the number1:")
b=input("Enter the number2:")
c=a+b
c
# Out:
# Enter the number1: 10
# Enter the number2: 20
# '1020'

# %%
input('enter a value:')
# Out:
# enter a value: 10
# '10'

# %%
a=int(input("Enter the number1:")) # int('10')
b=int(input("Enter the number2:")) # int('20')
c=a+b
c
# Out:
# Enter the number1: 10
# Enter the number2: 20
# 30

# %%
a=eval(input("Enter the number1:")) # int('10')
b=eval(input("Enter the number2:")) # int('20')
print(a+b)
# Out:
# Enter the number1: 10
# Enter the number2: 20
# 30

# %%
int('10') # 10
float('10.5') # 10.5
eval('10') # 10
eval('10.5') # 10.5

# %% [markdown]
# **Assignment Problems**

# %%
pi=intput("enter pi value")
r=intput("enter r value")
area_of_circle=pi*r*r
print(area_of_circle)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 pi=intput("enter pi value")
#       2 r=intput("enter r value")
#       3 area_of_circle=pi*r*r
#
# NameError: name 'intput' is not defined
