# %%
a=10
b=20
print(a)
print(b)
# Out:
# 10
# 20

# %%
a=10
b=20
print(a,b)
# Out:
# 10 20

# %%
a=10
b=20
a,b
# Out:
# (10, 20)

# %%
a=10
b=20
c=a+b
print(c)
# Out:
# 30

# %%
a=10
b=20
c=a+b
print("sum of 10 and 20 is 30")
print("sum of a and b is c")
print("sum of",a,"and",b,"is",c)
# Out:
# sum of 10 and 20 is 30
# sum of a and b is c
# sum of 10 and 20 is 30

# %%
a=10
b=20
c=a+b
print("sum of 10 and 20 is: 30")
print("sum of a and b is: c")
print("sum of",a,"and",b,"is:",c)
# Out:
# sum of 10 and 20 is: 30
# sum of a and b is: c
# sum of 10 and 20 is: 30

# %%
a=10
b=20
c=a+b
print("sum of 10 and 20 is= 30")
print("sum of a and b is= c")
print("sum of",a,"and",b,"is=",c)
# Out:
# sum of 10 and 20 is= 30
# sum of a and b is= c
# sum of 10 and 20 is= 30

# %%
name='Dhana'
age=30
city='AP'
print("my name is",name,"I am",age,"years old came from",city)
# Out:
# my name is Dhana I am 30 years old came from AP

# %% [markdown]
# **Method-2: Format**

# %%
a=10
b=20
c=a+b
print("sum of 10 and 20 is 30")
print("sum of {} and {} is {}")
print("sum of {a} and {b} is {c}")
print("sum of {} and {} is {}".format(a,b,c))
# Out:
# sum of 10 and 20 is 30
# sum of {} and {} is {}
# sum of {a} and {b} is {c}
# sum of 10 and 20 is 30

# %%
name='Dhana'
age=30
city='AP'
print("my name is Dhana I am 30 years old I am from AP")
print("my name is {} I am {} years old I am from {}".format(name,age,city))
# Out:
# my name is Dhana I am 30 years old I am from AP
# my name is Dhana I am 30 years old I am from AP

# %% [markdown]
# **Method-3: fstring**

# %%
a=10
b=20
c=a+b
print("sum of 10 and 20 is 30")
print("sum of {a} and {b} is {c}")
print(f"sum of {a} and {b} is {c}")
# Out:
# sum of 10 and 20 is 30
# sum of {a} and {b} is {c}
# sum of 10 and 20 is 30

# %%
a=100
b=200
c=a+b
print(c)
d=a-b
print(d)
e=a*b
print(e)
f=a/b
print(f)
# Out:
# 300
# -100
# 20000
# 0.5

# %%
a=100
b=200
print(f"sum of {a} and {b} is equal to {c}")
print(f"sub of {a} and {b} is equal to {d}")
print(f"multi of {a} and {b} is equal to {e}")
print(f"div of {a} and {b} is equal to {f}")
# Out:
# sum of 100 and 200 is equal to 300
# sub of 100 and 200 is equal to -100
# multi of 100 and 200 is equal to 20000
# div of 100 and 200 is equal to 0.5

# %%
a=100
b=200
c=300
d=avg=(a+b+c)/3
print(f"The avg of {a}, {b} and {c} is equal to {d}") # or
print(f"The avg of {a}, {b} and {c} is equal to {avg}")
print(f"The avg of {a}, {b} and {c} is equal to {(a+b+c)/3}")
# Out:
# The avg of 100, 200 and 300 is equal to 200.0
# The avg of 100, 200 and 300 is equal to 200.0
# The avg of 100, 200 and 300 is equal to 200.0

# %%
a=101
b=200
c=300
d=avg=(a+b+c)/3
print(f"The avg of {a}, {b} and {c} is equal to {avg}")
# Out:
# The avg of 101, 200 and 300 is equal to 200.33333333333334

# %%
round(34.77) # which is = 34
# Out:
# 35

# %%
round(34.57)
# Out:
# 35

# %%
round(34.477777,1) # 34.5
round(34.477777,2) # 34.48
round(34.477777,3) # 34.478
# Out:
# 34.478

# %% [markdown]
# **Assignmen Problems**

# %%
a=101
b=200
c=300
avg=round((a+b+c)/3) 
print(f"The avg of {a}, {b} and {c} is equal to {avg}")
# Out:
# The avg of 101, 200 and 300 is equal to 200

# %%
a=101
b=200
c=300
avg=(a+b+c)/3
avg1=round(avg,2)
print(f"The avg of {a}, {b} and {c} is equal to {avg1}")
# Out:
# The avg of 101, 200 and 300 is equal to 200.33

# %%
pi=3.14
r=100
area_of_circle=pi*r*r
print(f"Area of circle is: {area_of_circle}")
# Out:
# Area of circle is: 31400.0

# %%
b=10
h=20
area_of_triangle=0.5*b*h
print(f"Area of triangle is: {area_of_triangle}")
# Out:
# Area of triangle is: 100.0

# %%
print(area_of_triangle)
# Out:
# 100.0

# %%
bill_amount=1000
tip_per=10
tip_amount=bill_amount*tip_per/100
total_amount=bill_amount+tip_amount
print(total_amount)
# Out:
# 1100.0

# %%
salary=20000
tax_per=30 # per means percentage
tax_amount=salary*tax_per/100
total_amount=salary+tax_amount
print(f"total_amount is {total_amount}")
# Out:
# total_amount is 26000.0

# %%
dollar=5 # 1dollar=80rupees
rupee_value=80
total=dollar*rupee_value 
print(f"5$ value in rupees= {total}")
print("5$ value in rupees: 5$*80rs=400rs")
print("total amount in rupees:{dollar}$*{rupee_value}rs={total}")
print(f"total amount in rupees:{dollar}$*{rupee_value}rs={total}")
# Out:
# 5$ value in rupees= 400
# 5$ value in rupees: 5$*80rs=400rs
# total amount in rupees:{dollar}$*{rupee_value}rs={total}
# total amount in rupees:5$*80rs=400

# %%
kgs=50
pound=2.20462 # 1 kg=2.2 pounds
weight=30
converted_value=pound*kgs
print(f"converted value of weight of kg is {kgs} and pound is {pound}: {converted_value}")
# Out:
# converted value of weight of kg is 50 and pound is 2.20462: 110.231

# %%
weight_in_kgs=70
weight_in_pounds=2.2*weight_in_kgs
print(f"weight_in_pounds=2.2*weight_in_kgs={weight_in_kgs}*2.2={weight_in_pounds}lbs")
# Out:
# weight_in_pounds=2.2*weight_in_kgs=70*2.2=154.0lbs
