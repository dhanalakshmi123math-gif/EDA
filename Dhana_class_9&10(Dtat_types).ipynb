# %% [markdown]
# # CLASS_9

# %%
import os

# %%
os.getcwd()
# Out:
# 'C:\\Users\\dell\\Documents\\Polyspace_Workspace\\PYTHON_SESSIONS'

# %% [markdown]
# - we are using some inbuilt function

# %%
print()
type()
sum()
min()
max()
len()
len[] # wrong

# %%
os.getcwd()
# Out:
# 'C:\\Users\\dell\\Documents\\Polyspace_Workspace\\PYTHON_SESSIONS'

# %% [markdown]
# - if we miss brackets
#     - function
#     - bound method

# %% [markdown]
# # Data Types

# %%
- int
- float
- bool
- str
- complex
- range
- list
- tuple
- dict
- set
- frozenset
- bytes
- bytearray
- memoryview

# %%
python basics
    - Variables
    - Data types
    - Type casting, how to convert to one data type to another data type
    - print statements
    - basic codes
    - input, eval, round
    - packages or libraries i.e., very important
    - conditional statements
    - exceptional handlings
    - functions
    - for and while
python core
    - strings
    - list
        - list comprehension
    - tuple # 
    - dictionary
    - lambda functions
    - file handling
python advanced
    - oops EDA ML
python + stats : EDA
python + ML :
python + DL :
python + NLP :
python + Generative AI :

# %% [markdown]
# **Integer**

# %%
number=100
type(number)
# Out:
# int

# %% [markdown]
# **float**

# %%
number1=100.25
type(number1)
# Out:
# float

# %%
print(10e1) # 10*10
print(10e2) # 10*100
print(10e3) # 10*1000
# Out:
# 100.0
# 1000.0
# 10000.0

# %%
print(10e-1) # 10/10
print(10e-2) # 10/100
print(10e-3) # 10/1000
# Out:
# 1.0
# 0.1
# 0.01

# %%
-1.91946214e-3
# Out:
# -0.00191946214

# %%
print(10e+1) # 10e1==10e+1
print(10e+2) # 10e2==10e+2
print(10e+3) # 10e3==10e+3
# Out:
# 100.0
# 1000.0
# 10000.0

# %%
10e1==10e+1
# Out:
# True

# %%
10e2==10e+1
# Out:
# False

# %% [markdown]
# **Strings**

# %%
Dhana=200
Dhana
# Out:
# 200

# %%
Dhanaa
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 Dhanaaa
#
# NameError: name 'Dhanaaa' is not defined

# %%
city='Guntur'
type(city)
# Out:
# str

# %%
"Guntur"
# Out:
# 'Guntur'

# %%
print('Guntur')
# Out:
# Guntur

# %%
print(' Guntur ')
# Out:
#  Guntur

# %%
' Guntur    '
# Out:
# ' Guntur    '

# %%
len('hello')
# Out:
# 5

# %%
"Guntur'
# Out:
#   Cell In[32], line 1
#     "Guntur'
#     ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
len(   ' hello '    )
# Out:
# 7

# %%
len(' hello         ')
# Out:
# 15

# %% [markdown]
# # CLASS_10

# %% [markdown]
# **Name not found error**

# %% [markdown]
# - Name means the variable is not written before
# - And we are trying to use that
# - Check the variable name have you written or not

# %%
str1='python'
str2="python"
str1, str2
# Out:
# ('python', 'python')

# %%
str1='python'
str2="python"
print(str1)
print(str2)
# Out:
# python
# python

# %%
print('I like "python"')
# Out:
# I like "python"

# %%
print('I like 'python'')
# Out:
#   Cell In[40], line 1
#     print('I like 'python'')
#           ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %%
print("I like "python"")
# Out:
#   Cell In[4], line 1
#     print("I like "python"")
#           ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %%
print("I like 'python'")
# Out:
# I like 'python'

# %% [markdown]
# **Note**
# - Entire string in single quotes
# - Highlite the word in double quote vice versa

# %% [markdown]
# **Triple quotes**

# %%
"""My name is python
I am 10 years old
I came from Guntur"""
# Out:
# 'My name is python\nI am 10 years old\nI came from Guntur'

# %%
print("""My name is python
I am 10 years old
I came from Guntur""")
# Out:
# My name is python
# I am 10 years old
# I came from Guntur

# %% [markdown]
# **Doc string**
# - A doc string is used to write information about a Python file.
# - It is used to write information about functions.
# - It helps to make the user familiar with the Python code.
# - Doc strings are written using triple quotes (''' ''' or """ """).
# - It is nothing but a multiline comment used for documentation.
# - Never use triple quotes in a coding
# - Triple quotes means convey the information is called as Doc string

# %%
print('''My name is python
I am 10 years old
I came from Guntur''')
# Out:
# My name is python
# I am 10 years old
# I came from Guntur

# %%
import os

# %%
'''hello'''
"hello"
'hello'
""" hello """
# Out:
# ' hello '

# %%
import os
os.getcwd()
# take your cursor inside the bracket
# do shift+tab
# Out:
# 'C:\\Users\\dell\\Documents\\Polyspace_Workspace\\PYTHON_SESSIONS'

# %%
# Return a code string representing the current working directory

# %%
import random
random.random
# Out:
# <function Random.random()>

# %%
import random
random.random() # press shift+tab inside the brackets
# Out:
# 0.8622542615662511

# %%
random() -> x in the interval [0, 1).

# %%
import math
math.pow
# Out:
# <function math.pow(x, y, /)>

# %%
import math
math.pow(2,3)  # 2**3==2^3
# Out:
# 8.0

# %% [markdown]
# **boolean**

# %% [markdown]
# - when we ask a qn to a Machine
#     - True means yes i.e., 1
#     - True means ON
#     - False means No i.e., 0
#     - True means OFF

# %%
n1=True
type(n1)
# Out:
# bool

# %%
true="True" # true variable string
true=True # boolean
true=10 # int
true=10.5 # float
false=true 
false
# Out:
# 10.5

# %%
true="True" # true variable string
true=True # boolean
true=10 # int
false=true 
false
# Out:
# 10

# %%
true="True" # true variable string
true=True # boolean
false=true 
false
# Out:
# True

# %%
false="False"
false=false
false=10.5
true=false
true
# Out:
# 10.5

# %% [markdown]
# **List**
# - Array of elements represents in a square brackets

# %%
l=[10,20,30,40]
type(l)
# Out:
# list

# %%
l1=['Ramesh','Suresh','Sathish']
l2=[10,'Ramesh',10.5,True]
l3=[10,10,10]
l4=['Apple',[10,20,30]]
print(l1)
print(l2)
print(l3)
print(l4)
# Out:
# ['Ramesh', 'Suresh', 'Sathish']
# [10, 'Ramesh', 10.5, True]
# [10, 10, 10]
# ['Apple', [10, 20, 30]]

# %% [markdown]
# **tuple**

# %%
l=(10,20,30,40)
type(l)
# Out:
# tuple

# %%
l1=('Ramesh','Suresh','Sathish')
l2=(10,'Ramesh',10.5,True)
l3=(10,10,10)
l4=('Apple',[10,20,30])
print(l1)
print(l2)
print(l3)
print(l4)
# Out:
# ('Ramesh', 'Suresh', 'Sathish')
# (10, 'Ramesh', 10.5, True)
# (10, 10, 10)
# ('Apple', [10, 20, 30])

# %% [markdown]
# **Dictionary**

# %%
[] : list
() : tuple
{} : .....?

# %%
n1={10,20,30}
type(n1)
# Out:
# set

# %%
n1={10:20:30}
type(n1)
# Out:
#   Cell In[7], line 1
#     n1={10:20:30}
#              ^
# SyntaxError: invalid syntax

# %%
- It's a pair
- key and value pair
- seperated by :

# %%
d1={'wife':'husband'} # dictionary
s1={'wife','husband'} # set
d2={'key':'value'} # dictionary
