# %%
number1 = 10 # int 
number2=10.5 # float
name='Dhana Lakshmi' # string : str
value=True # boolean : bool
############################# Below are Important
fruits=['Apple','Banana','Cherry'] # list
names=('Dhana','Nani','Sravani') # tuple
age={30,26,27} # set
data={'Dhana':30,'Nani':26,'Sravani':27} # dictionary : dict

# %% [markdown]
# # Type casting:
# - Convert one data type to another data type

# %%
n1='100'
n2='200'
n1+n2
# Out:
# '100200'

# %% [markdown]
# # Case-1
# - int to float
# - int to str
# - int to bool

# %%
number=10
float(number),str(number),bool(number)
# Out:
# (10.0, '10', True)

# %%
float(-10),str(-10),bool(-10)
# Out:
# (-10.0, '-10', True)

# %%
float(0),str(0),bool(0)
# Out:
# (0.0, '0', False)

# %% [markdown]
# **Float to other data types**

# %%
number1=10.5
print(int(number1))
print(str(number1))
print(bool(number1))
# Out:
# 10
# 10.5
# True

# %%
number1=10.5
int(number1),str(number1),bool(number1)
# Out:
# (10, '10.5', True)

# %%
int(-10.5),str(-10.5),bool(-10.5)
# Out:
# (-10, '-10.5', True)

# %%
int(0.0),str(0.0),bool(0.0)
# Out:
# (0, '0.0', False)

# %% [markdown]
# - 0 means no value which is False OFF
# - any other numbers means True  ON

# %% [markdown]
# **String to other data types**

# %%
s1='10'
s2='10.5'
s3='apple'

# %%
print(int('10'))
print(float('10'))
print(bool('10'))
# Out:
# 10
# 10.0
# True

# %%
print(int('10.5')) # 10 is the int so error will occur
print(float('10.5'))
print(bool('10.5'))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 print(int('10.5')) # 10 is the int so error will occur
#       2 print(float('10.5'))
#       3 print(bool('10.5'))
#
# ValueError: invalid literal for int() with base 10: '10.5'

# %%
n1=10
print(n1)
n2=20
print(n2)
n3=Lenavo # Lenavo is not int
n4=100
n4=600
# Out:
# 10
# 20
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[21], line 5
#       3 n2=20
#       4 print(n2)
# ----> 5 n3=Lenavo # Lenavo is not int
#       6 n4=100
#       7 n4=600
#
# NameError: name 'Lenavo' is not defined

# %%
int('10.5') # error
int('10') # 10
# generally 10 is an integer
# but represented as a string
# both are same family

# %%
float('10.5'),int('10')
# Out:
# (10.5, 10)

# %%
float('10.5'),float('10')
# Out:
# (10.5, 10.0)

# %%
int(10) # 10
int(10.5) # 10
int('10') # 10
int('10.5') # error
float(10) # 10.0
float(10.5) # 10.5
float('10.5') # 10.5
float('10') # 10.5
# Out:
# 10.0

# %%
int('0'),float('0'),bool('0')
# 0       0.0        True (because value/character is available)
# Out:
# (0, 0.0, True)

# %%
int('0'),float('0'),bool('')
# 0       0.0        False (because value is not available)
# Out:
# (0, 0.0, False)

# %%
len('0'),len(''),len('Apple')
# yes     No     Yes ----> character/values are available or not
# Out:
# (1, 0, 5)

# %%
int('0.0'),float('0.0'),bool('0.0')
# error       0.0         True
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[41], line 1
# ----> 1 int('0.0'),float('0.0'),bool('0.0')
#       2 # error       0.0         True
#
# ValueError: invalid literal for int() with base 10: '0.0'

# %%
len('0.00')
# Out:
# 4

# %%
0.00
# Out:
# 0.0

# %%
float('apple') # error
int('apple') # error
bool('apple') # True

# %% [markdown]
# **Boolean to other data types**

# %%
int(True),float(True),str(True)
# Out:
# (1, 1.0, 'True')

# %%
int(False),float(False),str(False)
# Out:
# (0, 0.0, 'False')

# %%
int(10.5)
# Out:
# 10

# %%
int(10) # 10
float(10) # 10.0
str(10) # '10'
bool(10) # True
int(10.5) # 10 
float(10.5) # 10.5
str(10.5) # '10.5'
bool(10.5) # True
int('10') # 10
float('10') # 10.0
str('10') # '10'
bool('10') # True
int('10.5') # error
float('10.5') # 10.5
str('10.5') # '10.5'
bool('10.5') # True
int('apple') # error
float('apple') # error
str('apple') # 'apple'
bool('apple') # True
bool('') # False
int(True) # 1
float(True) # 1.0
str(True) # 'True'
int(False) # 0
float(False) # 0.0
str(False) # 'False'

# %%
float('10.5')
# Out:
# 10.5

# %%
int(float('10.5'))
# Out:
# 10

# %%
n1='100'
n2='200'
n1+n2 # '100'+'200'
# Out:
# '100200'

# %%
n1=int('100') # 100
n2=int('200') # 200
n1+n2
# Out:
# 300

# %%
n1='100'
n2='200'
n1+n2 # '100'+'200'
int(n1)+int(n2) # 100+200=300
# Out:
# 300

# %%
n1='100'
n2='200'
int(n1+n2)
# Out:
# 100200

# %%
n1='100.5'
n2='200'
n1+n2
# Out:
# '100.5200'

# %%
n1=float('100.5') # 100.5
n2=int('200') # 200
n1+n2
# Out:
# 300.5

# %%
n1=int('100.5') # error
n2=int('200') # 200
n1+n2
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[69], line 1
# ----> 1 n1=int('100.5') # error
#       2 n2=int('200') # 200
#       3 n1+n2
#
# ValueError: invalid literal for int() with base 10: '100.5'

# %% [markdown]
# **eval**

# %%
n1=eval('100.5')  # 
print(n1)
n2=eval('200') 
print(n2)
n1+n2
# Out:
# 100.5
# 200
# 300.5

# %%
n1=float('100.5') # 100.5
n2=float('200') # 200
n1+n2
# Out:
# 300.5

# %%
float(n1+n2)
# Out:
# 300.5

# %%
float(n1)+float(n2)
# Out:
# 300.5

# %%
'100'+'200' # '100200'
'100'+'****' # '100****'
'100.5'+'200' # '100.5200'
# Out:
# '100.5200'

# %%
100+'200' # error
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[83], line 1
# ----> 1 100+'200' # error
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %%
n1=eval('10.5') # error

# %%
eval(10) # error
eval(10.5) # error
eval('apple') # error
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[87], line 1
# ----> 1 eval(10) # error
#       2 eval(10.5) # error
#       3 eval('apple') # error
#
# TypeError: eval() arg 1 must be a string, bytes or code object

# %%
n1='100.5'
n2='200'
eva(n3)=float(n1)+int(n2)
n3
# Out:
#   Cell In[85], line 3
#     eva(n3)=float(n1)+int(n2)
#     ^
# SyntaxError: cannot assign to function call here. Maybe you meant '==' instead of '='?
